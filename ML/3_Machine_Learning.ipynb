# %% [markdown]
# # Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import skimage
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import gc
from tqdm import tqdm
import pickle
import copy

#Model creation
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
import scipy
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.metrics import matthews_corrcoef, make_scorer

#Oversamplig for unbalance
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE, ADASYN, SMOTENC
from imblearn.pipeline import Pipeline as Pipelineim
from sklearn.base import BaseEstimator, TransformerMixin

# %% [markdown]
# # Functions

# %% [markdown]
# ## Original functions

# %%
#Global dictionaries
mag_dict = {0:'40',1:'100',2:'200',3:'400'}
tt_dict = {0:'train',1:'test'}

# %%
def read_files(extractor, fold, mag):
  '''
  extractor: Feature extractor - String.
  mag: Magnification factor - int.
  fold: Fold number - int.
  Reads and splits the files as X_train, y_train, X_test, y_test
  '''

  data_train=pd.read_csv(f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/fold{fold}/train/{extractor}_f{fold}_train_{mag}x_fv.csv', delimiter='\t', index_col=0)
  X_train=data_train.iloc[:,1:-1]
  y_train=data_train.iloc[:,-1]
  df_patient_train=data_train.iloc[:,0:1] # Just patient Id's

  data_test=pd.read_csv(f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/fold{fold}/test/{extractor}_f{fold}_test_{mag}x_fv.csv', delimiter='\t', index_col=0)
  X_test=data_test.iloc[:,1:-1]
  y_test=data_test.iloc[:,-1]
  df_patient_test=data_test.iloc[:,0:1] # Just patient Id's

  return X_train, X_test, y_train, y_test, df_patient_train, df_patient_test

def read_files_csv(extractor, fold, mag):
  '''
  extractor: Feature extractor - String.
  mag: Magnification factor - int.
  fold: Fold number - int.
  Reads and splits the files as X_train, y_train, X_test, y_test
  '''

  data_train=pd.read_csv(f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/fold{fold+1}/train/{extractor}_f{fold+1}_train_{mag_dict[mag]}x_fv.csv', delimiter='\t', index_col=0)
  X_train=data_train.iloc[:,1:-1]
  y_train=data_train.iloc[:,-1]
  df_patient_train=data_train.iloc[:,0:1] # Just patient Id's

  data_test=pd.read_csv(f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/fold{fold+1}/test/{extractor}_f{fold+1}_test_{mag_dict[mag]}x_fv.csv', delimiter='\t', index_col=0)
  X_test=data_test.iloc[:,1:-1]
  y_test=data_test.iloc[:,-1]
  df_patient_test=data_test.iloc[:,0:1] # Just patient Id's

  return X_train, X_test, y_train, y_test, df_patient_train, df_patient_test

# %%
def knn_pipeline(X_train, y_train, X_test, y_test, df_patient_test):
  '''
  KNN pipeline with Standart scaler. 
  It returns Recognition rate.
  '''
  #pipe = Pipeline([('scaler', StandardScaler()),('classifier',KNeighborsClassifier(n_neighbors=1))])
  pipe = Pipeline([('scaler', StandardScaler()),('classifier',SVC(C=10,gamma=0.008))])
  #pipe = Pipeline([('scaler', StandardScaler()),('classifier',RandomForestClassifier(n_estimators=300, class_weight="balanced", max_depth=100, max_features= 'log2', criterion= 'gini') )])
  
  model = pipe.fit(X_train, y_train)
  y_pred = model.predict(X_test)

  acc = metrics.accuracy_score(y_test, y_pred)
  f1 = f1_score(y_test, y_pred, average='weighted')

  pscore = patient_score(df_patient_test, y_pred, y_test)
  rec_rate = recognition_rate(pscore)

  return rec_rate, acc, f1

def avg_rec_rate(mag,extractor, multi=False):
  '''
  mag: Magnification factor - int.
  extractor: Feature extractor - String.
  multi: If it is a multiclass vlassification - Boolean. Default=False.
  It calculates average recognition rate in all folds for each magnitification (40,100,200,400) for a specific feature extraction method. 
  '''
  r=0
  a=0
  f=0
  folds=[1,2,3,4,5]

  if multi == True:
    for i in folds:
      X_train, y_train, df_patient_train, X_test, y_test, df_patient_test = read_files_multi_class(extractor, i, mag)
      rec_rate, acc, f1 = knn_pipeline(X_train, y_train, X_test, y_test, df_patient_test)
      r += rec_rate
      a += acc
      f += f1

  else:
    for i in folds:
      X_train, X_test, y_train, y_test, _, df_patient_test = read_files(extractor, i, mag)
      rec_rate, acc, f1 = knn_pipeline(X_train, y_train, X_test, y_test, df_patient_test)
      r += rec_rate
      a += acc
      f += f1

  return r/len(folds), a/len(folds), f/len(folds) # Take the average

# %%
def patient_score(df_pat_test, y_p, y_t):
    '''
    Np : number of cancer images belong to the patient p.
    Nrec: number of images that are correctly classified for patient p. From y_pred
    Creation of DataFrame of Patient Id, y_pred, y_test, comparison of y_pred and y_test.
    '''
    y_pred_df=pd.DataFrame(y_p) # Create dataframe y_pred_df
    y_pred_df.columns = ['y_pred']

    y_test_df=pd.DataFrame(y_t) # Create dataframe y_test_df
    y_test_df.columns = ['y_test']
  
    df_p_test=df_pat_test.copy() # Copy the main dataframe with Patient ID's for test set.
    df_p_test.columns = ['patients'] # Naming the column in df_p_test
    df_p_test["y_test"]=y_test_df["y_test"] # Adding the dataframe y_test
    df_p_test["y_pred"]=y_pred_df["y_pred"] # Adding the dataframe y_pred
    df_p_test['comparison'] = np.where(df_p_test['y_test'] == df_p_test['y_pred'], 1, 0) # Adding the comparison coloumn, where y_pred==y_test, it's true.

    num_img_p=[]
    true_counts_p=[]
    for d in df_p_test.groupby('patients'): # Groupby the patients based on their Id's
      true_counts=d[1].comparison.sum() # The total correctly classfied images. The sum of comparison column. 
      true_counts_p.append(true_counts) # Creating Nrec value. 
      values=d[1].patients.value_counts(dropna=False) # Count number of apperances of patient Id per patient = # number of images obtained per patient.
      num_img_p.append(values[0]) # Creating Np value.

      p_score_arr=[]
      for i in range(len(num_img_p)): # Both arrays are in the same lenght 
        p_score=true_counts_p[i]/num_img_p[i] # For each index, calculate p score.
        p_score_arr.append(p_score) 

    return p_score_arr#, true_counts_p, num_img_p

def recognition_rate(p_score_arr):
  '''
  p_score_arr: p scores. - Array.
  It returns recognition rate.
  '''
  sum_p_score=np.array(p_score_arr).sum() # Sum of p score.
  rec_rate=sum_p_score/len(p_score_arr) # Calculation of the recognition rate. 
  return rec_rate

# %% [markdown]
# ## Pickle-based functions
# Functions using pickle and numpy arrays

# %%
def train_test_from_pickle(category, fold, mag):
  """
  Loads feature matrices, enpoints or patient's ID for each folder and magnification.
  It returns the train and test arrays of the selected category
  
  :param category: Category of the data (feature matrices (X), Enpoints (y) or patient's ID)
  :param f: Fold
  :param mag: Magnification
  :return: two np.arrays, train and test
  """
  path_train = f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/fold{fold+1}/train/{category}_f{fold+1}_train_{mag_dict[mag]}x_fv.p'
  path_test = f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/fold{fold+1}/test/{category}_f{fold+1}_test_{mag_dict[mag]}x_fv.p'
  with open(path_train,'rb') as handle:
    train_array = pickle.load(handle)
  with open(path_test, 'rb') as handle:
    test_array = pickle.load(handle)
  
  return train_array, test_array

def read_files_pickle(extractor, fold, mag): #Name given to mimic csv files function
  """
  Given the feature extractor name, folder nad magnifications, it returns the train-test split for the three categories (X, y, Patient ID)

  :param extractor: feature extractor name. e.g. extractor='GLCM'
  :param fold: fold -1
  :param mag: magnification following the mag_dicitonary indexing
  :return: train-test split
  """
  X_train, X_test = train_test_from_pickle(category=extractor, fold=fold, mag=mag)
  y_train, y_test = train_test_from_pickle(category='endpoints', fold=fold, mag=mag)
  ID_train, ID_test = train_test_from_pickle(category='ID', fold=fold, mag=mag)

  return X_train, X_test, y_train, y_test, ID_train, ID_test

def remove_correlated(X_train, X_test, max_corr):
  """
  Removes high correlated features. Input can be np. array of pandas df, but output will be pandas df.
  :param X_train: training feature matrix
  :param X_test: testing feature matrix
  :param corr: Maximum correlation accepted ebtween features.
  :return: Training and test un correlated feature matrices as dataframe
  """
  X_train = pd.DataFrame(X_train)
  X_test = pd.DataFrame(X_test)
  cor_matrix = X_train.corr().abs()
  upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(bool))
  to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > max_corr)]
  X_train_nocorr = X_train.drop(X_train[to_drop], axis=1)
  X_test_nocorr = X_test.drop(X_train[to_drop], axis=1)
  
  return X_train_nocorr, X_test_nocorr

def machine_learning_pipeline(X_train, X_test, y_train, y_test, ID_test, pipe, max_corr=1):
  """
  Main machine_learning pipeline.It receives the data (feature matrices, label and patients' ID) and produces the csv with the comparison between real and predicted labes. The model is also returned.
  
  :param X_train, X_test...etc: feature matrices, labels and patients' ID. X matrices are dataframes, the rest are np.arrays
  :param pipe: Pipeline defined using sklearn
  :param max_corr: Maximum correlation accepted among features
  :return: dataframe with the ID, prediction and real label, and model used
  """
  print(f'Input features: {X_train.shape[1]}\n')
  X_train_nocorr, X_test_nocorr = remove_correlated(X_train, X_test, max_corr=max_corr) #Remove correlated features from X_train and X_test
  print(f'No-correlated features: {X_train_nocorr.shape[1]}\n')
  model = pipe.fit(X_train_nocorr, y_train.ravel()) #Model fit
  y_pred = model.predict(X_test_nocorr) #Prediction

  y_pred = pd.DataFrame(y_pred) # Dataframe of predictions
  y_pred.columns = ['y_pred']
  y_test = pd.DataFrame(y_test) # Dataframe of test labels
  y_test.columns = ['y_test']
  df_comparison = pd.DataFrame(ID_test).copy() # Copy the main dataframe with Patient ID's for test set.
  df_comparison.columns = ['ID'] # Naming the column in df_p_test
  df_comparison["y_test"]=y_test["y_test"] # Adding the dataframe y_test
  df_comparison["y_pred"]=y_pred["y_pred"] # Adding the dataframe y_pred.
  df_comparison['comparison'] = np.where(df_comparison['y_test'] == df_comparison['y_pred'], 1, 0) # Adding the comparison coloumn, where y_pred==y_test, it's true.

  return df_comparison, model

def patient_score_beta(df_comparison):
  """
  Computes patient score based on the patients' ID as list. An extra list with the patient score and the ID as tuple is given to analyse individual response.
  :param df_comparison: Dataframe with 3 columns: ID, prediction and real label
  :return: two list with the pscores and pscores with ID
  """
  p_score_list = [] #List with the patient scores
  p_score_ID_list = [] #List with the patient score and IDs

  for d in df_comparison.groupby('ID'): # Groupby the patients based on their Id's
    true_counts=d[1].comparison.sum() # Creating Nrec value. 
    num_img=d[1].ID.value_counts(dropna=False)[0] #Creating Np value.
    p_score=true_counts/num_img # For each index, calculate p score, Nrec/Np
    p_score_list.append(p_score) #Append at the end of the patient score list
    p_score_ID_list.append([p_score,d[0]]) #Append at the end of the ID list
  
  return p_score_list, p_score_ID_list

def performance_metrics(df_comparison):
  """
  Here the performance metrics are computed. Currently patient score and recognition rate are the basis.
  Image-wise accuracy has also been added.
  :param df_comparison: Dataframe with 3 columns: ID, prediction and real label
  :return: performance metrics
  """
  p_score_list, p_score_ID_list = patient_score_beta(df_comparison) #Get patient scores
  rec_rate = np.mean(p_score_list) #Get recognition rate
  acc = df_comparison.comparison.mean()

  return p_score_list, p_score_ID_list, rec_rate, acc

def get_problematic_patients(p_score_ID_list, min_score=0.5):
  """
  Given a pscore with patients ID, the ID and performance of problematic (pscore<min_score) patients os given.
  :param p_score_ID_list: list of pscores and IDs
  :return: list of problematic patients
  """
  problem_list = []
  for p in p_score_ID_list:
    if p[0]<0.5:
      problem_list.append(p)
  return problem_list

def model2performance_metrics(extractor='PFTAS', read_files_type=read_files_csv, pipe=SVC(), max_corr=1, fold=0, mag=0):
  """
  Input ML model settings, as well as folder to extract
  :param extractor: name of extractor of features used
  :param read_files_type: type of file to be read (csv, pickle)
  :param pipe: Pipeline of the classification method.
  :param max_corr: Maximum correlation allowed between features
  :param fold, mag: known
  :return: metrics of the model + model. Additionally, problematic patients are displayed.
  """
  X_train, X_test, y_train, y_test, _, ID_test = read_files_type(extractor=extractor, fold=fold, mag=mag) #Split data
  df_comparison, model = machine_learning_pipeline(X_train, X_test, y_train, y_test, ID_test, pipe=pipe, max_corr=max_corr) #Main pipeline. Obtain comparison of labels
  p_score_list, p_score_ID_list, rec_rate, acc = performance_metrics(df_comparison) #Get performance metrics
  p_problem = get_problematic_patients(p_score_ID_list)

  print(f'-For fold {fold+1} and magnification {mag_dict[mag]}:\n') #Print metrics
  print(f'Recognition rate: {rec_rate}')
  print(f'Image-wise accuracy: {acc}')
  print(f'Problematic patients: {p_problem}\n') #Show problematic patients' ID and score

  return p_score_list, p_score_ID_list, rec_rate, acc, model

def result_all_folders(extractor, read_files_type, pipe, max_corr=1, mag=0):
  """
  All 5 folds are run for the same magnification. The extractor name, pipe definition as well as the max_correaltion have to be given
  :param extractor: name of extractor of features used
  :param read_files_type: type of file to be read (csv, pickle)
  :param pipe: Pipeline of the classification method.
  :param max_corr: Maximum correlation allowed between features
  :param mag: known
  :return: NONE
  """
  all_rec_rates = np.zeros(5) #To save recognition rates
  for fold in range(5):
    p_score_list, p_score_ID_list, rec_rate, acc, model = model2performance_metrics(extractor, read_files_type, pipe=pipe, max_corr=max_corr, fold=fold, mag=mag) #Fold-wise learning method
    all_rec_rates[fold] = rec_rate #save recognition rate
    if hasattr(model,'best_estimator_'):
      print(f'Grid best estimator: {model.best_estimator_}\n') #Print the best estimator hyperparameters of the grid search
      print(f'Best estimator number of Principal COmponents: {model.best_estimator_.named_steps["reductor"].explained_variance_ratio_.shape[0]}\n')
      print('############\n')

  print(f'---- Mean recognition rate for magnification {mag_dict[mag]}x: {all_rec_rates.mean()}') #Mean recognition rate (final metric)
  return model

# %%
def classifier_and_grid(method, grid='normal',verbose=1, reductor_components=[1]):
  """
  Definition of the classifier grid method for the hyperparameters search.
  :param method: learning method name (SVM, random forest, etc.)
  :param grid: type of grid search given (random or normal)
  """
  n_splits = 5
  #KNN
  if(method=='KNN'):
    param_grid = {'classifier__n_neighbors': list(range(1,40))}
    pipe = Pipeline([('scaler', StandardScaler()),('classifier',KNeighborsClassifier())])
    grid = GridSearchCV(pipe, param_grid, scoring='accuracy', verbose = verbose)
    return grid
  #KNN with PCA
  elif(method=='KNN_PCA'):
    param_grid = {'reductor__n_components': reductor_components,'classifier__n_neighbors': list(range(1,30))}
    pipe = Pipeline([('scaler', StandardScaler()),('reductor',PCA()),('classifier',KNeighborsClassifier())])
    grid = GridSearchCV(pipe, param_grid, scoring='accuracy', verbose = verbose)
    return grid
  #SVM with PCA
  elif(method=='SVM_PCA'):
    if(grid=='normal'):
      param_grid = {'reductor__n_components': reductor_components,'classifier__C': [0.1, 1, 10, 100],
              'classifier__gamma': [100, 10, 1, 0.1, 0.01, 0.001, 0.0001],
              'classifier__kernel': ['rbf']}
      pipe = Pipeline([('scaler', StandardScaler()),('reductor',PCA()),('classifier',SVC())])
      grid = GridSearchCV(pipe, param_grid, scoring='accuracy', cv = StratifiedKFold(n_splits=n_splits) ,verbose = verbose)
      return grid
    elif(grid=='random'):
      parameters = {'reductor__n_components': reductor_components,'classifier__C': scipy.stats.expon(scale=10), 'classifier__gamma': scipy.stats.expon(scale=.001), #Parameters for grid search
      'classifier__kernel': ['rbf'], 'classifier__class_weight':['balanced']}
      pipe = Pipeline([('scaler', StandardScaler()),('reductor',PCA()), ('classifier',SVC())]) #Definition of pipeline
      grid = RandomizedSearchCV(pipe, parameters,n_iter=20, scoring='accuracy', cv = StratifiedKFold(n_splits=n_splits) , verbose=verbose, return_train_score=False) #Random search
      return grid
  #SVM no PCA    
  elif(method=='SVM'):
    if(grid=='normal'):
      param_grid = {'classifier__C': [0.1, 1, 10, 100],
              'classifier__gamma': [100, 10, 1, 0.1, 0.01, 0.001, 0.0001],
              'classifier__kernel': ['rbf'],'classifier__class_weight':['balanced']}
      pipe = Pipeline([('scaler', StandardScaler()),('classifier',SVC())])
      grid = GridSearchCV(pipe, param_grid, scoring='accuracy', verbose = verbose)
      return grid
    elif(grid=='random'):
      parameters = {'classifier__C': scipy.stats.expon(scale=10), 'classifier__gamma': scipy.stats.expon(scale=.001), #Parameters for grid search
      'classifier__kernel': ['rbf'], 'classifier__class_weight':['balanced']}
      pipe = Pipeline([('scaler', StandardScaler()),('classifier',SVC())]) #Definition of pipeline
      grid = RandomizedSearchCV(pipe, parameters,n_iter=100, scoring='accuracy', verbose=verbose, return_train_score=False) #Random search
      return grid
  #Random forest
  elif(method=='RF'):
    param_grid = {'classifier__n_estimators': [100, 200, 400, 600, 800],}
    pipe = Pipeline([('scaler', StandardScaler()),('classifier',RandomForestClassifier())])
    grid = GridSearchCV(pipe, param_grid, scoring='accuracy', verbose = verbose)
    return grid
  #Random forest with PCA
  elif(method=='RF_PCA'):
    param_grid = {'reductor__n_components': reductor_components,'classifier__n_estimators': [100, 200, 400, 600, 800],}
    pipe = Pipeline([('scaler', StandardScaler()),('reductor',PCA()), ('classifier',RandomForestClassifier())])
    grid = GridSearchCV(pipe, param_grid, scoring='accuracy', verbose = verbose)
    return grid

# %% [markdown]
# ## Stratified and grouped functions

# %%
def classifier_and_grid_strat(X, y, ID, method, grid='normal',verbose=1, reductor_components=[1], scoring = 'accuracy', sampler =SMOTE()):
  """
  Definition of the classifier grid method for the hyperparameters search.
  :param method: learning method name (SVM, random forest, etc.)
  :param grid: type of grid search given (random or normal)
  """
  #CV split definition
  gkf = list(StratifiedGroupKFold(n_splits=5).split(X,y,groups=ID))
  #MCC scoring
  scoring = make_scorer(matthews_corrcoef) if scoring=='MCC' else None

  #KNN
  if(method=='KNN'):
    param_grid = {'classifier__n_neighbors': list(range(1,20))}
    pipe = Pipelineim([('scaler', StandardScaler()),('sampler',sampler),('classifier',KNeighborsClassifier())])
    grid = GridSearchCV(pipe, param_grid, scoring=scoring, cv = gkf,verbose = verbose)
    return grid
  #KNN with PCA
  elif(method=='KNN_PCA'):
    param_grid = {'reductor__n_components': reductor_components,'classifier__n_neighbors': list(range(1,20))}
    pipe = Pipelineim([('scaler', StandardScaler()),('reductor',PCA()), ('sampler',sampler), ('classifier',KNeighborsClassifier())])
    grid = GridSearchCV(pipe, param_grid, scoring=scoring, cv = gkf,verbose = verbose)
    return grid
  #SVM with PCA
  elif(method=='SVM_PCA'):
    if(grid=='normal'):
      param_grid = {'reductor__n_components': reductor_components,'classifier__C': [0.1, 1, 10, 100],
              'classifier__gamma': [100, 10, 1, 0.1, 0.01, 0.001, 0.0001],
              'classifier__kernel': ['rbf']}
      pipe = Pipelineim([('scaler', StandardScaler()),('reductor',PCA()),('sampler',sampler),('classifier',SVC())])
      grid = GridSearchCV(pipe, param_grid, scoring=scoring, cv = gkf, verbose = verbose)
      return grid
    elif(grid=='random'):
      parameters = {'reductor__n_components': reductor_components,'classifier__C': scipy.stats.expon(scale=10), 'classifier__gamma': scipy.stats.expon(scale=.001), #Parameters for grid search
      'classifier__kernel': ['rbf'], 'classifier__class_weight':['balanced']}
      pipe = Pipelineim([('scaler', StandardScaler()),('reductor',PCA()), ('sampler',sampler), ('classifier',SVC())]) #Definition of pipeline
      grid = RandomizedSearchCV(pipe, parameters,n_iter=15, scoring=scoring, cv = gkf, verbose=verbose, return_train_score=False) #Random search
      return grid
  #SVM no PCA    
  elif(method=='SVM'):
    if(grid=='normal'):
      param_grid = {'classifier__C': [0.1, 1, 10, 100],
              'classifier__gamma': [100, 10, 1, 0.1, 0.01, 0.001, 0.0001],
              'classifier__kernel': ['rbf'],'classifier__class_weight':['balanced']}
      pipe = Pipelineim([('scaler', StandardScaler()),('sampler',sampler),('classifier',SVC())])
      grid = GridSearchCV(pipe, param_grid, scoring=scoring, cv = gkf, verbose = verbose)
      return grid
    elif(grid=='random'):
      parameters = {'classifier__C': scipy.stats.expon(scale=10), 'classifier__gamma': scipy.stats.expon(scale=.001), #Parameters for grid search
      'classifier__kernel': ['rbf'], 'classifier__class_weight':['balanced']}
      pipe = Pipelineim([('scaler', StandardScaler()),('sampler',sampler),('classifier',SVC())]) #Definition of pipeline
      grid = RandomizedSearchCV(pipe, parameters,n_iter=15, scoring=scoring, cv = gkf, verbose=verbose, return_train_score=False) #Random search
      return grid
  #Random forest
  elif(method=='RF'):
    param_grid = {'classifier__n_estimators': [100, 200, 400, 600],}
    pipe = Pipelineim([('scaler', StandardScaler()),('sampler',sampler),('classifier',RandomForestClassifier())])
    grid = GridSearchCV(pipe, param_grid, scoring=scoring, cv = gkf, verbose = verbose)
    return grid
  #Random forest with PCA
  elif(method=='RF_PCA'):
    param_grid = {'reductor__n_components': reductor_components,'classifier__n_estimators': [100, 200, 400, 600],}
    pipe = Pipelineim([('scaler', StandardScaler()),('reductor',PCA()),('sampler',sampler), ('classifier',RandomForestClassifier())])
    grid = GridSearchCV(pipe, param_grid, scoring=scoring, cv = gkf, verbose = verbose)
    return grid


#Define identity transformation
class IdentityTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self, input_array, y=None):
        return self
    
    def transform(self, input_array, y=None):
        return input_array*1

def model2performance_metrics_strat(extractor='dense', method = 'SVM', grid = 'normal', verbose = 1, reductor_components = [1], scoring = 'accuracy', sampler = SMOTE(), max_corr=1, fold=0, mag=0):
  """
  Input ML model settings, as well as folder to extract
  :param extractor: name of extractor of features used
  :param read_files_type: type of file to be read (csv, pickle)
  :param pipe: Pipeline of the classification method.
  :param max_corr: Maximum correlation allowed between features
  :param fold, mag: known
  :return: metrics of the model + model. Additionally, problematic patients are displayed.
  """
  read_files_type=read_files_pickle if (extractor in ['dense','GLCM']) else read_files_csv #Read files type

  X_train, X_test, y_train, y_test, ID_train, ID_test = read_files_type(extractor=extractor, fold=fold, mag=mag) #Split data
  pipe = classifier_and_grid_strat(X_train, y_train, ID_train, method, grid = grid, verbose=verbose, reductor_components=reductor_components, scoring = scoring, sampler =sampler) #Defining pipe
  df_comparison, model = machine_learning_pipeline(X_train, X_test, y_train, y_test, ID_test, pipe=pipe, max_corr=max_corr) #Main pipeline. Obtain comparison of labels
  p_score_list, p_score_ID_list, rec_rate, acc = performance_metrics(df_comparison) #Get performance metrics
  p_problem = get_problematic_patients(p_score_ID_list)

  print(f'-For fold {fold+1} and magnification {mag_dict[mag]}:\n') #Print metrics
  print(f'Recognition rate: {rec_rate}')
  print(f'Image-wise accuracy: {acc}')
  print(f'Problematic patients: {p_problem}\n') #Show problematic patients' ID and score

  return p_score_list, p_score_ID_list, rec_rate, acc, model

def result_all_folders_strat(extractor = 'dense', method = 'SVM', grid = 'normal', verbose = 1, reductor_components = [1], scoring = 'accuracy', sampler = IdentityTransformer(), max_corr=1, mag=0):
  """
  All 5 folds are run for the same magnification. The extractor name, pipe definition as well as the max_correaltion have to be given
  :param extractor: name of extractor of features used
  :param read_files_type: type of file to be read (csv, pickle)
  :param pipe: Pipeline of the classification method.
  :param max_corr: Maximum correlation allowed between features
  :param mag: known
  :return: NONE
  """
  all_rec_rates = np.zeros(5) #To save recognition rates
  for fold in range(5):
    p_score_list, p_score_ID_list, rec_rate, acc, model = model2performance_metrics_strat(extractor=extractor, method = method, grid = grid, verbose = verbose, reductor_components = reductor_components, scoring = scoring, sampler = sampler, max_corr=max_corr, fold=fold, mag=mag) #Fold-wise learning method
    all_rec_rates[fold] = rec_rate #save recognition rate
    if hasattr(model,'best_estimator_'):
      print(f'Grid best estimator: {model.best_estimator_}\n') #Print the best estimator hyperparameters of the grid search
      #print(f'Best estimator number of Principal Components: {model.best_estimator_.named_steps["reductor"].explained_variance_ratio_.shape[0]}\n')
      print('############\n')
  rec_rate_mean = all_rec_rates.mean()
  rec_rate_std = all_rec_rates.std()
  print(f'---- Mean recognition rate for magnification {mag_dict[mag]}x: {rec_rate_mean}') #Mean recognition rate (final metric)
  return rec_rate_mean, rec_rate_std

# %%
#Functions to print information about the models evolution based on neighbors number.
def KNN_neighbors_check(model):
  """
  After fitting a KNN model check the model evolution
  :param model: trained KNN model
  :return: NONE, plot graph  
  """
  cv_results = model.cv_results_
  scores_mean = cv_results['mean_test_score']
  scores_mean = np.array(scores_mean)
  scores_mean
  scores_sd = cv_results['std_test_score']
  scores_sd = np.array(scores_sd)

  # Plot Grid search scores
  fig, ax = plt.subplots(1,1)

  # # 
  ax.plot(scores_mean, '-o')
  ax.set_title("Grid Search Scores", fontsize=20, fontweight='bold')
  ax.set_xlabel('Num_neighbors', fontsize=16)
  ax.set_ylabel('CV Average Score', fontsize=16)
  ax.grid('on')
  plt.imshow()

# %% [markdown]
# # Model training

# %% [markdown]
# ## Binary classification

# %%
super_matrix = np.zeros((12,9),dtype='object') #Matrix containing all results
i = 0 #Matrix row counter
for extractor in ['fbp','GLCM','PFTAS','Gabor','dense']: #fbp is LBP typo #All features used
  for method in ['KNN','KNN_PCA','SVM','SVM_PCA','RF','RF_PCA']: #All method used
    for sampler in [SMOTE(), IdentityTransformer()]: #With oversample of withour
      
      #Magnification level model comparison
      rec_rate_all = np.zeros((4,2)) #Row is magnification, column is mean and standard deviation
      for mag in [0,1,2,3]:

        grid = 'random'
        verbose = 3
        reductor_components = [0.95] #For PCA only
        scoring = 'MCC'
        max_corr = 0.99

        #Predict for magnification
        rec_rate_all[mag,:] = result_all_folders_strat(extractor = extractor, method = method, grid = grid, verbose = verbose, reductor_components = reductor_components, scoring = scoring, sampler =sampler, max_corr=max_corr, mag = mag)
      super_matrix[i,1:] = rec_rate_all.ravel()
      super_matrix[i,0] = extractor+'_'+method+'_'+str(sampler)
      i = i+1
with open(f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/Machine_Learning/Results/super_matrix_{extractor}.p','wb') as handle:
  pickle.dump(super_matrix, handle, pickle.HIGHEST_PROTOCOL)
# Out:
# Streaming output truncated to the last 5000 lines.
# [CV 5/5] END classifier__C=5.692183948934706, classifier__class_weight=balanced, classifier__gamma=0.0035371823813547362, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.151 total time=   0.2s
# [CV 1/5] END classifier__C=13.056462572313004, classifier__class_weight=balanced, classifier__gamma=0.00040249082218104566, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.030 total time=   0.2s
# [CV 2/5] END classifier__C=13.056462572313004, classifier__class_weight=balanced, classifier__gamma=0.00040249082218104566, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.215 total time=   0.2s
# [CV 3/5] END classifier__C=13.056462572313004, classifier__class_weight=balanced, classifier__gamma=0.00040249082218104566, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.188 total time=   0.2s
# [CV 4/5] END classifier__C=13.056462572313004, classifier__class_weight=balanced, classifier__gamma=0.00040249082218104566, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.243 total time=   0.2s
# [CV 5/5] END classifier__C=13.056462572313004, classifier__class_weight=balanced, classifier__gamma=0.00040249082218104566, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.197 total time=   0.2s
# [CV 1/5] END classifier__C=21.72313257699639, classifier__class_weight=balanced, classifier__gamma=0.0003963775354112774, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.022 total time=   0.2s
# [CV 2/5] END classifier__C=21.72313257699639, classifier__class_weight=balanced, classifier__gamma=0.0003963775354112774, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.212 total time=   0.2s
# [CV 3/5] END classifier__C=21.72313257699639, classifier__class_weight=balanced, classifier__gamma=0.0003963775354112774, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.188 total time=   0.2s
# [CV 4/5] END classifier__C=21.72313257699639, classifier__class_weight=balanced, classifier__gamma=0.0003963775354112774, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.238 total time=   0.2s
# [CV 5/5] END classifier__C=21.72313257699639, classifier__class_weight=balanced, classifier__gamma=0.0003963775354112774, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.157 total time=   0.2s
# -For fold 4 and magnification 400:
#
# Recognition rate: 0.6073113806126764
# Image-wise accuracy: 0.5942028985507246
# Problematic patients: [[0.0, '13418DE'], [0.3793103448275862, '16184CD'], [0.13333333333333333, '16448'], [0.23076923076923078, '16601'], [0.06896551724137931, '16716'], [0.0, '18842D'], [0.2, '190EF'], [0.07142857142857142, '21998EF'], [0.23333333333333334, '22549AB'], [0.1, '22549CD'], [0.23076923076923078, '22704']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)), ('sampler', SMOTE()),
#                 ('classifier',
#                  SVC(C=17.817512989520743, class_weight='balanced',
#                      gamma=0.0005124158852419974))])
#
# ############
#
# Input features: 10
#
# No-correlated features: 10
#
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END classifier__C=8.06193773854925, classifier__class_weight=balanced, classifier__gamma=0.0028375821984098666, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.298 total time=   0.1s
# [CV 2/5] END classifier__C=8.06193773854925, classifier__class_weight=balanced, classifier__gamma=0.0028375821984098666, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.043 total time=   0.1s
# [CV 3/5] END classifier__C=8.06193773854925, classifier__class_weight=balanced, classifier__gamma=0.0028375821984098666, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.243 total time=   0.1s
# [CV 4/5] END classifier__C=8.06193773854925, classifier__class_weight=balanced, classifier__gamma=0.0028375821984098666, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.176 total time=   0.1s
# [CV 5/5] END classifier__C=8.06193773854925, classifier__class_weight=balanced, classifier__gamma=0.0028375821984098666, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.228 total time=   0.1s
# [CV 1/5] END classifier__C=21.84849788143054, classifier__class_weight=balanced, classifier__gamma=0.0005052093139052841, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.298 total time=   0.1s
# [CV 2/5] END classifier__C=21.84849788143054, classifier__class_weight=balanced, classifier__gamma=0.0005052093139052841, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.073 total time=   0.1s
# [CV 3/5] END classifier__C=21.84849788143054, classifier__class_weight=balanced, classifier__gamma=0.0005052093139052841, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.265 total time=   0.1s
# [CV 4/5] END classifier__C=21.84849788143054, classifier__class_weight=balanced, classifier__gamma=0.0005052093139052841, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.181 total time=   0.1s
# [CV 5/5] END classifier__C=21.84849788143054, classifier__class_weight=balanced, classifier__gamma=0.0005052093139052841, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.215 total time=   0.1s
# [CV 1/5] END classifier__C=1.9889290953581322, classifier__class_weight=balanced, classifier__gamma=0.0003565279007342284, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.340 total time=   0.1s
# [CV 2/5] END classifier__C=1.9889290953581322, classifier__class_weight=balanced, classifier__gamma=0.0003565279007342284, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.112 total time=   0.1s
# [CV 3/5] END classifier__C=1.9889290953581322, classifier__class_weight=balanced, classifier__gamma=0.0003565279007342284, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.268 total time=   0.1s
# [CV 4/5] END classifier__C=1.9889290953581322, classifier__class_weight=balanced, classifier__gamma=0.0003565279007342284, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.313 total time=   0.1s
# [CV 5/5] END classifier__C=1.9889290953581322, classifier__class_weight=balanced, classifier__gamma=0.0003565279007342284, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.169 total time=   0.1s
# [CV 1/5] END classifier__C=10.14365016570887, classifier__class_weight=balanced, classifier__gamma=0.00047962469938020035, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.291 total time=   0.1s
# [CV 2/5] END classifier__C=10.14365016570887, classifier__class_weight=balanced, classifier__gamma=0.00047962469938020035, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.029 total time=   0.1s
# [CV 3/5] END classifier__C=10.14365016570887, classifier__class_weight=balanced, classifier__gamma=0.00047962469938020035, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.254 total time=   0.1s
# [CV 4/5] END classifier__C=10.14365016570887, classifier__class_weight=balanced, classifier__gamma=0.00047962469938020035, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.203 total time=   0.1s
# [CV 5/5] END classifier__C=10.14365016570887, classifier__class_weight=balanced, classifier__gamma=0.00047962469938020035, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.242 total time=   0.1s
# [CV 1/5] END classifier__C=0.8236915746740616, classifier__class_weight=balanced, classifier__gamma=0.0021998763189326194, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.291 total time=   0.1s
# [CV 2/5] END classifier__C=0.8236915746740616, classifier__class_weight=balanced, classifier__gamma=0.0021998763189326194, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.063 total time=   0.1s
# [CV 3/5] END classifier__C=0.8236915746740616, classifier__class_weight=balanced, classifier__gamma=0.0021998763189326194, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.280 total time=   0.1s
# [CV 4/5] END classifier__C=0.8236915746740616, classifier__class_weight=balanced, classifier__gamma=0.0021998763189326194, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.219 total time=   0.1s
# [CV 5/5] END classifier__C=0.8236915746740616, classifier__class_weight=balanced, classifier__gamma=0.0021998763189326194, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.175 total time=   0.1s
# [CV 1/5] END classifier__C=0.024668742709445343, classifier__class_weight=balanced, classifier__gamma=0.0011354319271183085, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.361 total time=   0.1s
# [CV 2/5] END classifier__C=0.024668742709445343, classifier__class_weight=balanced, classifier__gamma=0.0011354319271183085, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.127 total time=   0.1s
# [CV 3/5] END classifier__C=0.024668742709445343, classifier__class_weight=balanced, classifier__gamma=0.0011354319271183085, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.291 total time=   0.1s
# [CV 4/5] END classifier__C=0.024668742709445343, classifier__class_weight=balanced, classifier__gamma=0.0011354319271183085, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.384 total time=   0.1s
# [CV 5/5] END classifier__C=0.024668742709445343, classifier__class_weight=balanced, classifier__gamma=0.0011354319271183085, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.141 total time=   0.1s
# [CV 1/5] END classifier__C=2.4344474552296975, classifier__class_weight=balanced, classifier__gamma=0.00033812788095967806, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.333 total time=   0.1s
# [CV 2/5] END classifier__C=2.4344474552296975, classifier__class_weight=balanced, classifier__gamma=0.00033812788095967806, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.013 total time=   0.1s
# [CV 3/5] END classifier__C=2.4344474552296975, classifier__class_weight=balanced, classifier__gamma=0.00033812788095967806, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.258 total time=   0.1s
# [CV 4/5] END classifier__C=2.4344474552296975, classifier__class_weight=balanced, classifier__gamma=0.00033812788095967806, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.296 total time=   0.1s
# [CV 5/5] END classifier__C=2.4344474552296975, classifier__class_weight=balanced, classifier__gamma=0.00033812788095967806, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.175 total time=   0.1s
# [CV 1/5] END classifier__C=4.930301672570435, classifier__class_weight=balanced, classifier__gamma=0.0016483900311611032, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.284 total time=   0.1s
# [CV 2/5] END classifier__C=4.930301672570435, classifier__class_weight=balanced, classifier__gamma=0.0016483900311611032, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.114 total time=   0.1s
# [CV 3/5] END classifier__C=4.930301672570435, classifier__class_weight=balanced, classifier__gamma=0.0016483900311611032, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.249 total time=   0.1s
# [CV 4/5] END classifier__C=4.930301672570435, classifier__class_weight=balanced, classifier__gamma=0.0016483900311611032, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.229 total time=   0.1s
# [CV 5/5] END classifier__C=4.930301672570435, classifier__class_weight=balanced, classifier__gamma=0.0016483900311611032, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.235 total time=   0.1s
# [CV 1/5] END classifier__C=3.6348365172683446, classifier__class_weight=balanced, classifier__gamma=0.0005223493855732317, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.312 total time=   0.1s
# [CV 2/5] END classifier__C=3.6348365172683446, classifier__class_weight=balanced, classifier__gamma=0.0005223493855732317, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.150 total time=   0.1s
# [CV 3/5] END classifier__C=3.6348365172683446, classifier__class_weight=balanced, classifier__gamma=0.0005223493855732317, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.259 total time=   0.1s
# [CV 4/5] END classifier__C=3.6348365172683446, classifier__class_weight=balanced, classifier__gamma=0.0005223493855732317, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.196 total time=   0.1s
# [CV 5/5] END classifier__C=3.6348365172683446, classifier__class_weight=balanced, classifier__gamma=0.0005223493855732317, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.215 total time=   0.1s
# [CV 1/5] END classifier__C=0.31235823543647423, classifier__class_weight=balanced, classifier__gamma=0.0002611961790921209, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.413 total time=   0.1s
# [CV 2/5] END classifier__C=0.31235823543647423, classifier__class_weight=balanced, classifier__gamma=0.0002611961790921209, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.189 total time=   0.1s
# [CV 3/5] END classifier__C=0.31235823543647423, classifier__class_weight=balanced, classifier__gamma=0.0002611961790921209, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.301 total time=   0.1s
# [CV 4/5] END classifier__C=0.31235823543647423, classifier__class_weight=balanced, classifier__gamma=0.0002611961790921209, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.424 total time=   0.1s
# [CV 5/5] END classifier__C=0.31235823543647423, classifier__class_weight=balanced, classifier__gamma=0.0002611961790921209, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.097 total time=   0.1s
# [CV 1/5] END classifier__C=21.730076468847482, classifier__class_weight=balanced, classifier__gamma=0.0034078831946755795, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.270 total time=   0.1s
# [CV 2/5] END classifier__C=21.730076468847482, classifier__class_weight=balanced, classifier__gamma=0.0034078831946755795, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.096 total time=   0.1s
# [CV 3/5] END classifier__C=21.730076468847482, classifier__class_weight=balanced, classifier__gamma=0.0034078831946755795, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.249 total time=   0.1s
# [CV 4/5] END classifier__C=21.730076468847482, classifier__class_weight=balanced, classifier__gamma=0.0034078831946755795, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.178 total time=   0.1s
# [CV 5/5] END classifier__C=21.730076468847482, classifier__class_weight=balanced, classifier__gamma=0.0034078831946755795, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.271 total time=   0.1s
# [CV 1/5] END classifier__C=5.807583984979528, classifier__class_weight=balanced, classifier__gamma=0.0005922397842608852, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.305 total time=   0.1s
# [CV 2/5] END classifier__C=5.807583984979528, classifier__class_weight=balanced, classifier__gamma=0.0005922397842608852, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.150 total time=   0.1s
# [CV 3/5] END classifier__C=5.807583984979528, classifier__class_weight=balanced, classifier__gamma=0.0005922397842608852, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.254 total time=   0.1s
# [CV 4/5] END classifier__C=5.807583984979528, classifier__class_weight=balanced, classifier__gamma=0.0005922397842608852, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.220 total time=   0.1s
# [CV 5/5] END classifier__C=5.807583984979528, classifier__class_weight=balanced, classifier__gamma=0.0005922397842608852, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.175 total time=   0.1s
# [CV 1/5] END classifier__C=11.536424552636369, classifier__class_weight=balanced, classifier__gamma=0.0020338471065144974, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.284 total time=   0.1s
# [CV 2/5] END classifier__C=11.536424552636369, classifier__class_weight=balanced, classifier__gamma=0.0020338471065144974, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.097 total time=   0.1s
# [CV 3/5] END classifier__C=11.536424552636369, classifier__class_weight=balanced, classifier__gamma=0.0020338471065144974, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.259 total time=   0.1s
# [CV 4/5] END classifier__C=11.536424552636369, classifier__class_weight=balanced, classifier__gamma=0.0020338471065144974, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.196 total time=   0.1s
# [CV 5/5] END classifier__C=11.536424552636369, classifier__class_weight=balanced, classifier__gamma=0.0020338471065144974, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.242 total time=   0.1s
# [CV 1/5] END classifier__C=8.378392314211963, classifier__class_weight=balanced, classifier__gamma=0.00022061229046179244, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.326 total time=   0.1s
# [CV 2/5] END classifier__C=8.378392314211963, classifier__class_weight=balanced, classifier__gamma=0.00022061229046179244, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.168 total time=   0.1s
# [CV 3/5] END classifier__C=8.378392314211963, classifier__class_weight=balanced, classifier__gamma=0.00022061229046179244, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.254 total time=   0.1s
# [CV 4/5] END classifier__C=8.378392314211963, classifier__class_weight=balanced, classifier__gamma=0.00022061229046179244, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.291 total time=   0.1s
# [CV 5/5] END classifier__C=8.378392314211963, classifier__class_weight=balanced, classifier__gamma=0.00022061229046179244, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.182 total time=   0.1s
# [CV 1/5] END classifier__C=41.36166463440101, classifier__class_weight=balanced, classifier__gamma=0.003597889885559468, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.301 total time=   0.1s
# [CV 2/5] END classifier__C=41.36166463440101, classifier__class_weight=balanced, classifier__gamma=0.003597889885559468, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.084 total time=   0.1s
# [CV 3/5] END classifier__C=41.36166463440101, classifier__class_weight=balanced, classifier__gamma=0.003597889885559468, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.238 total time=   0.1s
# [CV 4/5] END classifier__C=41.36166463440101, classifier__class_weight=balanced, classifier__gamma=0.003597889885559468, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.170 total time=   0.1s
# [CV 5/5] END classifier__C=41.36166463440101, classifier__class_weight=balanced, classifier__gamma=0.003597889885559468, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.278 total time=   0.1s
# -For fold 5 and magnification 400:
#
# Recognition rate: 0.6958377590591478
# Image-wise accuracy: 0.6485355648535565
# Problematic patients: [[0.125, '16184'], [0.13333333333333333, '19979C'], [0.13559322033898305, '21998AB'], [0.46875, '21998CD'], [0.3333333333333333, '22549CD'], [0.15384615384615385, '9133']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)), ('sampler', SMOTE()),
#                 ('classifier',
#                  SVC(C=0.31235823543647423, class_weight='balanced',
#                      gamma=0.0002611961790921209))])
#
# ############
#
# ---- Mean recognition rate for magnification 400x: 0.6318160692185213
# Input features: 10
#
# No-correlated features: 10
#
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END classifier__C=2.8001056501309796, classifier__class_weight=balanced, classifier__gamma=0.0007813462578905188, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.118 total time=   0.1s
# [CV 2/5] END classifier__C=2.8001056501309796, classifier__class_weight=balanced, classifier__gamma=0.0007813462578905188, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.303 total time=   0.1s
# [CV 3/5] END classifier__C=2.8001056501309796, classifier__class_weight=balanced, classifier__gamma=0.0007813462578905188, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.010 total time=   0.1s
# [CV 4/5] END classifier__C=2.8001056501309796, classifier__class_weight=balanced, classifier__gamma=0.0007813462578905188, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.169 total time=   0.1s
# [CV 5/5] END classifier__C=2.8001056501309796, classifier__class_weight=balanced, classifier__gamma=0.0007813462578905188, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.148 total time=   0.1s
# [CV 1/5] END classifier__C=7.457529369319467, classifier__class_weight=balanced, classifier__gamma=9.140285320002826e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.140 total time=   0.1s
# [CV 2/5] END classifier__C=7.457529369319467, classifier__class_weight=balanced, classifier__gamma=9.140285320002826e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.274 total time=   0.1s
# [CV 3/5] END classifier__C=7.457529369319467, classifier__class_weight=balanced, classifier__gamma=9.140285320002826e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.151 total time=   0.1s
# [CV 4/5] END classifier__C=7.457529369319467, classifier__class_weight=balanced, classifier__gamma=9.140285320002826e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.122 total time=   0.1s
# [CV 5/5] END classifier__C=7.457529369319467, classifier__class_weight=balanced, classifier__gamma=9.140285320002826e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.280 total time=   0.1s
# [CV 1/5] END classifier__C=15.639000428746066, classifier__class_weight=balanced, classifier__gamma=6.914504157461066e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.120 total time=   0.1s
# [CV 2/5] END classifier__C=15.639000428746066, classifier__class_weight=balanced, classifier__gamma=6.914504157461066e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.301 total time=   0.1s
# [CV 3/5] END classifier__C=15.639000428746066, classifier__class_weight=balanced, classifier__gamma=6.914504157461066e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.024 total time=   0.1s
# [CV 4/5] END classifier__C=15.639000428746066, classifier__class_weight=balanced, classifier__gamma=6.914504157461066e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.174 total time=   0.1s
# [CV 5/5] END classifier__C=15.639000428746066, classifier__class_weight=balanced, classifier__gamma=6.914504157461066e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.252 total time=   0.1s
# [CV 1/5] END classifier__C=4.52731622319742, classifier__class_weight=balanced, classifier__gamma=0.00266441011237462, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.080 total time=   0.1s
# [CV 2/5] END classifier__C=4.52731622319742, classifier__class_weight=balanced, classifier__gamma=0.00266441011237462, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.355 total time=   0.1s
# [CV 3/5] END classifier__C=4.52731622319742, classifier__class_weight=balanced, classifier__gamma=0.00266441011237462, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.065 total time=   0.1s
# [CV 4/5] END classifier__C=4.52731622319742, classifier__class_weight=balanced, classifier__gamma=0.00266441011237462, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.042 total time=   0.1s
# [CV 5/5] END classifier__C=4.52731622319742, classifier__class_weight=balanced, classifier__gamma=0.00266441011237462, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.030 total time=   0.1s
# [CV 1/5] END classifier__C=4.577588345846945, classifier__class_weight=balanced, classifier__gamma=0.0004271158331096904, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.118 total time=   0.1s
# [CV 2/5] END classifier__C=4.577588345846945, classifier__class_weight=balanced, classifier__gamma=0.0004271158331096904, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.277 total time=   0.1s
# [CV 3/5] END classifier__C=4.577588345846945, classifier__class_weight=balanced, classifier__gamma=0.0004271158331096904, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.010 total time=   0.1s
# [CV 4/5] END classifier__C=4.577588345846945, classifier__class_weight=balanced, classifier__gamma=0.0004271158331096904, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.149 total time=   0.1s
# [CV 5/5] END classifier__C=4.577588345846945, classifier__class_weight=balanced, classifier__gamma=0.0004271158331096904, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.152 total time=   0.1s
# [CV 1/5] END classifier__C=3.2331935259506146, classifier__class_weight=balanced, classifier__gamma=0.0012697529514531084, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.085 total time=   0.1s
# [CV 2/5] END classifier__C=3.2331935259506146, classifier__class_weight=balanced, classifier__gamma=0.0012697529514531084, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.357 total time=   0.1s
# [CV 3/5] END classifier__C=3.2331935259506146, classifier__class_weight=balanced, classifier__gamma=0.0012697529514531084, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.009 total time=   0.1s
# [CV 4/5] END classifier__C=3.2331935259506146, classifier__class_weight=balanced, classifier__gamma=0.0012697529514531084, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.170 total time=   0.1s
# [CV 5/5] END classifier__C=3.2331935259506146, classifier__class_weight=balanced, classifier__gamma=0.0012697529514531084, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.038 total time=   0.1s
# [CV 1/5] END classifier__C=2.6270056586166617, classifier__class_weight=balanced, classifier__gamma=0.00026406784125450284, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.140 total time=   0.1s
# [CV 2/5] END classifier__C=2.6270056586166617, classifier__class_weight=balanced, classifier__gamma=0.00026406784125450284, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.274 total time=   0.1s
# [CV 3/5] END classifier__C=2.6270056586166617, classifier__class_weight=balanced, classifier__gamma=0.00026406784125450284, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.143 total time=   0.1s
# [CV 4/5] END classifier__C=2.6270056586166617, classifier__class_weight=balanced, classifier__gamma=0.00026406784125450284, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.122 total time=   0.1s
# [CV 5/5] END classifier__C=2.6270056586166617, classifier__class_weight=balanced, classifier__gamma=0.00026406784125450284, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.280 total time=   0.1s
# [CV 1/5] END classifier__C=10.319912423707292, classifier__class_weight=balanced, classifier__gamma=0.003008279649286071, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.111 total time=   0.1s
# [CV 2/5] END classifier__C=10.319912423707292, classifier__class_weight=balanced, classifier__gamma=0.003008279649286071, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.338 total time=   0.1s
# [CV 3/5] END classifier__C=10.319912423707292, classifier__class_weight=balanced, classifier__gamma=0.003008279649286071, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.101 total time=   0.1s
# [CV 4/5] END classifier__C=10.319912423707292, classifier__class_weight=balanced, classifier__gamma=0.003008279649286071, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.028 total time=   0.1s
# [CV 5/5] END classifier__C=10.319912423707292, classifier__class_weight=balanced, classifier__gamma=0.003008279649286071, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.025 total time=   0.1s
# [CV 1/5] END classifier__C=9.648900038203852, classifier__class_weight=balanced, classifier__gamma=0.0005829531556564045, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.064 total time=   0.1s
# [CV 2/5] END classifier__C=9.648900038203852, classifier__class_weight=balanced, classifier__gamma=0.0005829531556564045, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.388 total time=   0.1s
# [CV 3/5] END classifier__C=9.648900038203852, classifier__class_weight=balanced, classifier__gamma=0.0005829531556564045, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.064 total time=   0.1s
# [CV 4/5] END classifier__C=9.648900038203852, classifier__class_weight=balanced, classifier__gamma=0.0005829531556564045, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.178 total time=   0.1s
# [CV 5/5] END classifier__C=9.648900038203852, classifier__class_weight=balanced, classifier__gamma=0.0005829531556564045, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.028 total time=   0.1s
# [CV 1/5] END classifier__C=14.430923437785534, classifier__class_weight=balanced, classifier__gamma=0.0028249193891692996, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.111 total time=   0.1s
# [CV 2/5] END classifier__C=14.430923437785534, classifier__class_weight=balanced, classifier__gamma=0.0028249193891692996, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.335 total time=   0.1s
# [CV 3/5] END classifier__C=14.430923437785534, classifier__class_weight=balanced, classifier__gamma=0.0028249193891692996, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.090 total time=   0.1s
# [CV 4/5] END classifier__C=14.430923437785534, classifier__class_weight=balanced, classifier__gamma=0.0028249193891692996, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.008 total time=   0.1s
# [CV 5/5] END classifier__C=14.430923437785534, classifier__class_weight=balanced, classifier__gamma=0.0028249193891692996, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.025 total time=   0.1s
# [CV 1/5] END classifier__C=38.86931504243274, classifier__class_weight=balanced, classifier__gamma=0.0007482709441530051, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.053 total time=   0.1s
# [CV 2/5] END classifier__C=38.86931504243274, classifier__class_weight=balanced, classifier__gamma=0.0007482709441530051, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.347 total time=   0.1s
# [CV 3/5] END classifier__C=38.86931504243274, classifier__class_weight=balanced, classifier__gamma=0.0007482709441530051, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.093 total time=   0.1s
# [CV 4/5] END classifier__C=38.86931504243274, classifier__class_weight=balanced, classifier__gamma=0.0007482709441530051, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.048 total time=   0.1s
# [CV 5/5] END classifier__C=38.86931504243274, classifier__class_weight=balanced, classifier__gamma=0.0007482709441530051, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.036 total time=   0.1s
# [CV 1/5] END classifier__C=9.339259807943423, classifier__class_weight=balanced, classifier__gamma=0.0007354638161152032, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.058 total time=   0.1s
# [CV 2/5] END classifier__C=9.339259807943423, classifier__class_weight=balanced, classifier__gamma=0.0007354638161152032, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.342 total time=   0.1s
# [CV 3/5] END classifier__C=9.339259807943423, classifier__class_weight=balanced, classifier__gamma=0.0007354638161152032, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.057 total time=   0.1s
# [CV 4/5] END classifier__C=9.339259807943423, classifier__class_weight=balanced, classifier__gamma=0.0007354638161152032, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.127 total time=   0.1s
# [CV 5/5] END classifier__C=9.339259807943423, classifier__class_weight=balanced, classifier__gamma=0.0007354638161152032, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.036 total time=   0.1s
# [CV 1/5] END classifier__C=7.923081608215284, classifier__class_weight=balanced, classifier__gamma=0.0015441340555781451, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.069 total time=   0.1s
# [CV 2/5] END classifier__C=7.923081608215284, classifier__class_weight=balanced, classifier__gamma=0.0015441340555781451, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.365 total time=   0.1s
# [CV 3/5] END classifier__C=7.923081608215284, classifier__class_weight=balanced, classifier__gamma=0.0015441340555781451, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.034 total time=   0.1s
# [CV 4/5] END classifier__C=7.923081608215284, classifier__class_weight=balanced, classifier__gamma=0.0015441340555781451, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.122 total time=   0.1s
# [CV 5/5] END classifier__C=7.923081608215284, classifier__class_weight=balanced, classifier__gamma=0.0015441340555781451, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.036 total time=   0.1s
# [CV 1/5] END classifier__C=1.8841880508186133, classifier__class_weight=balanced, classifier__gamma=5.008181579386899e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.164 total time=   0.1s
# [CV 2/5] END classifier__C=1.8841880508186133, classifier__class_weight=balanced, classifier__gamma=5.008181579386899e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.295 total time=   0.1s
# [CV 3/5] END classifier__C=1.8841880508186133, classifier__class_weight=balanced, classifier__gamma=5.008181579386899e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.000 total time=   0.1s
# [CV 4/5] END classifier__C=1.8841880508186133, classifier__class_weight=balanced, classifier__gamma=5.008181579386899e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.091 total time=   0.1s
# [CV 5/5] END classifier__C=1.8841880508186133, classifier__class_weight=balanced, classifier__gamma=5.008181579386899e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.170 total time=   0.1s
# [CV 1/5] END classifier__C=1.7273351712550444, classifier__class_weight=balanced, classifier__gamma=1.162589634893853e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.000 total time=   0.1s
# [CV 2/5] END classifier__C=1.7273351712550444, classifier__class_weight=balanced, classifier__gamma=1.162589634893853e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.000 total time=   0.1s
# [CV 3/5] END classifier__C=1.7273351712550444, classifier__class_weight=balanced, classifier__gamma=1.162589634893853e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.000 total time=   0.1s
# [CV 4/5] END classifier__C=1.7273351712550444, classifier__class_weight=balanced, classifier__gamma=1.162589634893853e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.000 total time=   0.1s
# [CV 5/5] END classifier__C=1.7273351712550444, classifier__class_weight=balanced, classifier__gamma=1.162589634893853e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.000 total time=   0.1s
# -For fold 1 and magnification 40:
#
# Recognition rate: 0.6369536496866103
# Image-wise accuracy: 0.5892617449664429
# Problematic patients: [[0.34375, '13412'], [0.058823529411764705, '15687B'], [0.0, '16184'], [0.058823529411764705, '19979C'], [0.06896551724137931, '21998AB'], [0.10810810810810811, '21998CD'], [0.22857142857142856, '22549G'], [0.23076923076923078, '9133']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)),
#                 ('sampler', IdentityTransformer()),
#                 ('classifier',
#                  SVC(C=7.457529369319467, class_weight='balanced',
#                      gamma=9.140285320002826e-05))])
#
# ############
#
# Input features: 10
#
# No-correlated features: 10
#
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END classifier__C=14.940287593175519, classifier__class_weight=balanced, classifier__gamma=0.0004955946936086748, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.125 total time=   0.1s
# [CV 2/5] END classifier__C=14.940287593175519, classifier__class_weight=balanced, classifier__gamma=0.0004955946936086748, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.059 total time=   0.1s
# [CV 3/5] END classifier__C=14.940287593175519, classifier__class_weight=balanced, classifier__gamma=0.0004955946936086748, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.022 total time=   0.1s
# [CV 4/5] END classifier__C=14.940287593175519, classifier__class_weight=balanced, classifier__gamma=0.0004955946936086748, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.004 total time=   0.1s
# [CV 5/5] END classifier__C=14.940287593175519, classifier__class_weight=balanced, classifier__gamma=0.0004955946936086748, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.347 total time=   0.1s
# [CV 1/5] END classifier__C=10.853811636994656, classifier__class_weight=balanced, classifier__gamma=0.0009552529190997924, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.127 total time=   0.1s
# [CV 2/5] END classifier__C=10.853811636994656, classifier__class_weight=balanced, classifier__gamma=0.0009552529190997924, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.033 total time=   0.1s
# [CV 3/5] END classifier__C=10.853811636994656, classifier__class_weight=balanced, classifier__gamma=0.0009552529190997924, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.079 total time=   0.1s
# [CV 4/5] END classifier__C=10.853811636994656, classifier__class_weight=balanced, classifier__gamma=0.0009552529190997924, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.020 total time=   0.1s
# [CV 5/5] END classifier__C=10.853811636994656, classifier__class_weight=balanced, classifier__gamma=0.0009552529190997924, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.335 total time=   0.1s
# [CV 1/5] END classifier__C=0.30747734081457695, classifier__class_weight=balanced, classifier__gamma=0.001050746147130415, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.007 total time=   0.1s
# [CV 2/5] END classifier__C=0.30747734081457695, classifier__class_weight=balanced, classifier__gamma=0.001050746147130415, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.102 total time=   0.1s
# [CV 3/5] END classifier__C=0.30747734081457695, classifier__class_weight=balanced, classifier__gamma=0.001050746147130415, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.072 total time=   0.1s
# [CV 4/5] END classifier__C=0.30747734081457695, classifier__class_weight=balanced, classifier__gamma=0.001050746147130415, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.110 total time=   0.1s
# [CV 5/5] END classifier__C=0.30747734081457695, classifier__class_weight=balanced, classifier__gamma=0.001050746147130415, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.249 total time=   0.1s
# [CV 1/5] END classifier__C=0.8996434279521934, classifier__class_weight=balanced, classifier__gamma=0.0006604341120749912, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.027 total time=   0.1s
# [CV 2/5] END classifier__C=0.8996434279521934, classifier__class_weight=balanced, classifier__gamma=0.0006604341120749912, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.113 total time=   0.1s
# [CV 3/5] END classifier__C=0.8996434279521934, classifier__class_weight=balanced, classifier__gamma=0.0006604341120749912, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.078 total time=   0.2s
# [CV 4/5] END classifier__C=0.8996434279521934, classifier__class_weight=balanced, classifier__gamma=0.0006604341120749912, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.089 total time=   0.1s
# [CV 5/5] END classifier__C=0.8996434279521934, classifier__class_weight=balanced, classifier__gamma=0.0006604341120749912, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.220 total time=   0.1s
# [CV 1/5] END classifier__C=34.552625795571814, classifier__class_weight=balanced, classifier__gamma=0.0010561125105821925, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.115 total time=   0.1s
# [CV 2/5] END classifier__C=34.552625795571814, classifier__class_weight=balanced, classifier__gamma=0.0010561125105821925, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.067 total time=   0.1s
# [CV 3/5] END classifier__C=34.552625795571814, classifier__class_weight=balanced, classifier__gamma=0.0010561125105821925, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.159 total time=   0.1s
# [CV 4/5] END classifier__C=34.552625795571814, classifier__class_weight=balanced, classifier__gamma=0.0010561125105821925, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.071 total time=   0.1s
# [CV 5/5] END classifier__C=34.552625795571814, classifier__class_weight=balanced, classifier__gamma=0.0010561125105821925, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.322 total time=   0.1s
# [CV 1/5] END classifier__C=4.250649072129943, classifier__class_weight=balanced, classifier__gamma=3.4241769656376256e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.061 total time=   0.1s
# [CV 2/5] END classifier__C=4.250649072129943, classifier__class_weight=balanced, classifier__gamma=3.4241769656376256e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.119 total time=   0.1s
# [CV 3/5] END classifier__C=4.250649072129943, classifier__class_weight=balanced, classifier__gamma=3.4241769656376256e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.097 total time=   0.1s
# [CV 4/5] END classifier__C=4.250649072129943, classifier__class_weight=balanced, classifier__gamma=3.4241769656376256e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.238 total time=   0.1s
# [CV 5/5] END classifier__C=4.250649072129943, classifier__class_weight=balanced, classifier__gamma=3.4241769656376256e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.193 total time=   0.1s
# [CV 1/5] END classifier__C=1.6566089587421189, classifier__class_weight=balanced, classifier__gamma=0.005135824419052723, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.104 total time=   0.1s
# [CV 2/5] END classifier__C=1.6566089587421189, classifier__class_weight=balanced, classifier__gamma=0.005135824419052723, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.062 total time=   0.1s
# [CV 3/5] END classifier__C=1.6566089587421189, classifier__class_weight=balanced, classifier__gamma=0.005135824419052723, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.081 total time=   0.1s
# [CV 4/5] END classifier__C=1.6566089587421189, classifier__class_weight=balanced, classifier__gamma=0.005135824419052723, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.049 total time=   0.1s
# [CV 5/5] END classifier__C=1.6566089587421189, classifier__class_weight=balanced, classifier__gamma=0.005135824419052723, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.361 total time=   0.1s
# [CV 1/5] END classifier__C=5.152016889385283, classifier__class_weight=balanced, classifier__gamma=0.0009617348552324547, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.093 total time=   0.1s
# [CV 2/5] END classifier__C=5.152016889385283, classifier__class_weight=balanced, classifier__gamma=0.0009617348552324547, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.069 total time=   0.1s
# [CV 3/5] END classifier__C=5.152016889385283, classifier__class_weight=balanced, classifier__gamma=0.0009617348552324547, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.083 total time=   0.1s
# [CV 4/5] END classifier__C=5.152016889385283, classifier__class_weight=balanced, classifier__gamma=0.0009617348552324547, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.021 total time=   0.1s
# [CV 5/5] END classifier__C=5.152016889385283, classifier__class_weight=balanced, classifier__gamma=0.0009617348552324547, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.391 total time=   0.1s
# [CV 1/5] END classifier__C=6.770710303706768, classifier__class_weight=balanced, classifier__gamma=0.000848344611127529, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.103 total time=   0.1s
# [CV 2/5] END classifier__C=6.770710303706768, classifier__class_weight=balanced, classifier__gamma=0.000848344611127529, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.062 total time=   0.1s
# [CV 3/5] END classifier__C=6.770710303706768, classifier__class_weight=balanced, classifier__gamma=0.000848344611127529, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.068 total time=   0.1s
# [CV 4/5] END classifier__C=6.770710303706768, classifier__class_weight=balanced, classifier__gamma=0.000848344611127529, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.016 total time=   0.1s
# [CV 5/5] END classifier__C=6.770710303706768, classifier__class_weight=balanced, classifier__gamma=0.000848344611127529, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.377 total time=   0.1s
# [CV 1/5] END classifier__C=20.956378234479427, classifier__class_weight=balanced, classifier__gamma=0.0008490435075139473, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.136 total time=   0.1s
# [CV 2/5] END classifier__C=20.956378234479427, classifier__class_weight=balanced, classifier__gamma=0.0008490435075139473, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.049 total time=   0.1s
# [CV 3/5] END classifier__C=20.956378234479427, classifier__class_weight=balanced, classifier__gamma=0.0008490435075139473, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.117 total time=   0.1s
# [CV 4/5] END classifier__C=20.956378234479427, classifier__class_weight=balanced, classifier__gamma=0.0008490435075139473, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.005 total time=   0.1s
# [CV 5/5] END classifier__C=20.956378234479427, classifier__class_weight=balanced, classifier__gamma=0.0008490435075139473, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.326 total time=   0.1s
# [CV 1/5] END classifier__C=14.326000532905427, classifier__class_weight=balanced, classifier__gamma=2.2793621254973108e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.018 total time=   0.1s
# [CV 2/5] END classifier__C=14.326000532905427, classifier__class_weight=balanced, classifier__gamma=2.2793621254973108e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.101 total time=   0.1s
# [CV 3/5] END classifier__C=14.326000532905427, classifier__class_weight=balanced, classifier__gamma=2.2793621254973108e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.023 total time=   0.1s
# [CV 4/5] END classifier__C=14.326000532905427, classifier__class_weight=balanced, classifier__gamma=2.2793621254973108e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.077 total time=   0.2s
# [CV 5/5] END classifier__C=14.326000532905427, classifier__class_weight=balanced, classifier__gamma=2.2793621254973108e-05, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.229 total time=   0.1s
# [CV 1/5] END classifier__C=4.754319561382105, classifier__class_weight=balanced, classifier__gamma=0.000728963002946551, classifier__kernel=rbf, reductor__n_components=0.95;, score=0.019 total time=   0.1s
# [CV 2/5] END classifier__C=4.754319561382105, classifier__class_weight=balanced, classifier__gamma=0.000728963002946551, classifier__kernel=rbf, reductor__n_components=0.95;, score=-0.111 total time=   0.1s
# ...
# [CV 4/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.236 total time=   0.6s
# [CV 5/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.241 total time=   0.7s
# [CV 1/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.157 total time=   1.2s
# [CV 2/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.329 total time=   1.2s
# [CV 3/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.345 total time=   1.2s
# [CV 4/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.229 total time=   1.2s
# [CV 5/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.270 total time=   1.2s
# [CV 1/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.141 total time=   1.8s
# [CV 2/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.344 total time=   1.8s
# [CV 3/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.368 total time=   1.8s
# [CV 4/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.229 total time=   1.8s
# [CV 5/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.236 total time=   1.8s
# -For fold 5 and magnification 200:
#
# Recognition rate: 0.6166276005596271
# Image-wise accuracy: 0.6077922077922078
# Problematic patients: [[0.05714285714285714, '16184'], [0.06666666666666667, '190EF'], [0.0, '19854C'], [0.1875, '19979C'], [0.17307692307692307, '21998AB'], [0.2972972972972973, '21998CD'], [0.0, '22549AB'], [0.03225806451612903, '22549CD'], [0.1875, '3411F'], [0.02631578947368421, '9133']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)),
#                 ('sampler', IdentityTransformer()),
#                 ('classifier', RandomForestClassifier(n_estimators=200))])
#
# ############
#
# ---- Mean recognition rate for magnification 200x: 0.6411017918407677
# Input features: 10
#
# No-correlated features: 10
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.310 total time=   0.4s
# [CV 2/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.206 total time=   0.4s
# [CV 3/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=-0.120 total time=   0.4s
# [CV 4/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.251 total time=   0.3s
# [CV 5/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.273 total time=   0.3s
# [CV 1/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.318 total time=   0.7s
# [CV 2/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.113 total time=   0.6s
# [CV 3/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=-0.160 total time=   0.6s
# [CV 4/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.264 total time=   0.7s
# [CV 5/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.236 total time=   0.7s
# [CV 1/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.310 total time=   1.3s
# [CV 2/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.152 total time=   1.2s
# [CV 3/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=-0.127 total time=   1.2s
# [CV 4/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.278 total time=   1.3s
# [CV 5/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.225 total time=   1.2s
# [CV 1/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.371 total time=   1.8s
# [CV 2/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.165 total time=   1.8s
# [CV 3/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=-0.094 total time=   1.8s
# [CV 4/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.240 total time=   1.9s
# [CV 5/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.236 total time=   1.9s
# -For fold 1 and magnification 400:
#
# Recognition rate: 0.6727160612931274
# Image-wise accuracy: 0.6412213740458015
# Problematic patients: [[0.13333333333333333, '15687B'], [0.125, '16184'], [0.0, '18842D'], [0.15254237288135594, '21998AB'], [0.09375, '21998CD'], [0.06896551724137931, '22549G'], [0.3888888888888889, '23222AB'], [0.4117647058823529, '29960CD'], [0.11538461538461539, '9133']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)),
#                 ('sampler', IdentityTransformer()),
#                 ('classifier', RandomForestClassifier())])
#
# ############
#
# Input features: 10
#
# No-correlated features: 10
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.071 total time=   0.4s
# [CV 2/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.067 total time=   0.4s
# [CV 3/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.335 total time=   0.4s
# [CV 4/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.169 total time=   0.4s
# [CV 5/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.091 total time=   0.4s
# [CV 1/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.119 total time=   0.7s
# [CV 2/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.111 total time=   0.7s
# [CV 3/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.306 total time=   0.7s
# [CV 4/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.137 total time=   0.7s
# [CV 5/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.078 total time=   0.7s
# [CV 1/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.032 total time=   1.3s
# [CV 2/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.079 total time=   1.4s
# [CV 3/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.341 total time=   1.4s
# [CV 4/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.115 total time=   1.3s
# [CV 5/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.111 total time=   1.4s
# [CV 1/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.093 total time=   2.0s
# [CV 2/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.102 total time=   2.0s
# [CV 3/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.332 total time=   2.0s
# [CV 4/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.147 total time=   1.9s
# [CV 5/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.105 total time=   1.9s
# -For fold 2 and magnification 400:
#
# Recognition rate: 0.656208152795019
# Image-wise accuracy: 0.6750902527075813
# Problematic patients: [[0.0, '14134E'], [0.4, '15275'], [0.0, '15687B'], [0.0, '18842D'], [0.10344827586206896, '22549G'], [0.0, '23060AB'], [0.23529411764705882, '29960CD']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)),
#                 ('sampler', IdentityTransformer()),
#                 ('classifier', RandomForestClassifier(n_estimators=600))])
#
# ############
#
# Input features: 10
#
# No-correlated features: 10
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.114 total time=   0.4s
# [CV 2/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.052 total time=   0.4s
# [CV 3/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.108 total time=   0.4s
# [CV 4/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.070 total time=   0.4s
# [CV 5/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.180 total time=   0.4s
# [CV 1/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.106 total time=   0.7s
# [CV 2/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.052 total time=   0.7s
# [CV 3/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.123 total time=   0.7s
# [CV 4/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.012 total time=   0.7s
# [CV 5/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.157 total time=   0.7s
# [CV 1/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.132 total time=   1.3s
# [CV 2/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.029 total time=   1.3s
# [CV 3/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.146 total time=   1.3s
# [CV 4/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.006 total time=   1.3s
# [CV 5/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.141 total time=   1.3s
# [CV 1/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.143 total time=   1.8s
# [CV 2/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.021 total time=   1.9s
# [CV 3/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.103 total time=   1.9s
# [CV 4/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.025 total time=   1.9s
# [CV 5/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.170 total time=   1.9s
# -For fold 3 and magnification 400:
#
# Recognition rate: 0.6473400862306656
# Image-wise accuracy: 0.6638513513513513
# Problematic patients: [[0.0, '14134E'], [0.0, '19854C'], [0.14285714285714285, '21978AB'], [0.13333333333333333, '22549CD'], [0.05128205128205128, '22704'], [0.47058823529411764, '29960CD']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)),
#                 ('sampler', IdentityTransformer()),
#                 ('classifier', RandomForestClassifier())])
#
# ############
#
# Input features: 10
#
# No-correlated features: 10
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.044 total time=   0.4s
# [CV 2/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.088 total time=   0.3s
# [CV 3/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.207 total time=   0.4s
# [CV 4/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.144 total time=   0.4s
# [CV 5/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.160 total time=   0.4s
# [CV 1/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=-0.025 total time=   0.7s
# [CV 2/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.103 total time=   0.7s
# [CV 3/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.131 total time=   0.7s
# [CV 4/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.123 total time=   0.7s
# [CV 5/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.082 total time=   0.7s
# [CV 1/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.001 total time=   1.2s
# [CV 2/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.103 total time=   1.3s
# [CV 3/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.225 total time=   1.3s
# [CV 4/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.129 total time=   1.2s
# [CV 5/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.138 total time=   1.2s
# [CV 1/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.011 total time=   1.8s
# [CV 2/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.149 total time=   1.8s
# [CV 3/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.213 total time=   1.9s
# [CV 4/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.101 total time=   1.8s
# [CV 5/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.202 total time=   1.9s
# -For fold 4 and magnification 400:
#
# Recognition rate: 0.6827722958240027
# Image-wise accuracy: 0.6553945249597424
# Problematic patients: [[0.41379310344827586, '16184CD'], [0.125, '18842D'], [0.25, '19854C'], [0.0, '21998EF'], [0.1, '22549AB'], [0.13333333333333333, '22549CD'], [0.1282051282051282, '22704']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)),
#                 ('sampler', IdentityTransformer()),
#                 ('classifier', RandomForestClassifier(n_estimators=600))])
#
# ############
#
# Input features: 10
#
# No-correlated features: 10
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.299 total time=   0.3s
# [CV 2/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.025 total time=   0.3s
# [CV 3/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=-0.016 total time=   0.3s
# [CV 4/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.361 total time=   0.3s
# [CV 5/5] END classifier__n_estimators=100, reductor__n_components=0.95;, score=0.211 total time=   0.3s
# [CV 1/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.315 total time=   0.6s
# [CV 2/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.025 total time=   0.6s
# [CV 3/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=-0.016 total time=   0.6s
# [CV 4/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.337 total time=   0.6s
# [CV 5/5] END classifier__n_estimators=200, reductor__n_components=0.95;, score=0.211 total time=   0.6s
# [CV 1/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.323 total time=   1.2s
# [CV 2/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.035 total time=   1.2s
# [CV 3/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=-0.062 total time=   1.1s
# [CV 4/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.355 total time=   1.1s
# [CV 5/5] END classifier__n_estimators=400, reductor__n_components=0.95;, score=0.210 total time=   1.1s
# [CV 1/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.323 total time=   1.7s
# [CV 2/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.046 total time=   1.7s
# [CV 3/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=-0.062 total time=   1.6s
# [CV 4/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.358 total time=   1.7s
# [CV 5/5] END classifier__n_estimators=600, reductor__n_components=0.95;, score=0.218 total time=   1.7s
# -For fold 5 and magnification 400:
#
# Recognition rate: 0.636958607179535
# Image-wise accuracy: 0.6317991631799164
# Problematic patients: [[0.08333333333333333, '16184'], [0.0, '19854C'], [0.4, '19979C'], [0.2033898305084746, '21998AB'], [0.09375, '21998CD'], [0.1, '22549AB'], [0.16666666666666666, '22549CD'], [0.0625, '23060CD'], [0.35294117647058826, '3411F'], [0.15384615384615385, '9133']]
#
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)),
#                 ('sampler', IdentityTransformer()),
#                 ('classifier', RandomForestClassifier(n_estimators=600))])
#
# ############
#
# ---- Mean recognition rate for magnification 400x: 0.6591990406644699

# %% [markdown]
# ### Combination of features (No improvements)

# %%
extractor_1 = 'PFTAS'
read_files_type_1 = read_files_csv
extractor_2 = 'dense'
read_files_type_2 = read_files_pickle
extractor_3 = 'fbp'
read_files_type_3 = read_files_csv

# fold=1
# mag=1
pipe = classifier_and_grid(method='SVM_PCA',grid='random',verbose=1, reductor_components=[0.9,0.95,0.99])

for mag in range(4):
  all_rec_rate = np.zeros(5)
  print(f'For magnification {mag_dict[mag]}\n')
  for fold in range(5):
    X_train_1, X_test_1, _, _, _, _ = read_files_type_1(extractor=extractor_1, fold=fold, mag=mag) #Split data
    X_train_2, X_test_2, y_train, y_test, _, ID_test = read_files_type_2(extractor=extractor_2, fold=fold, mag=mag) #Split data
    X_train_3, X_test_3, _, _, _, _ = read_files_type_3(extractor=extractor_3, fold=fold, mag=mag) #Split data
    #Transforming to np
    X_train_1 = X_train_1.to_numpy()
    X_test_1 = X_test_1.to_numpy()

    X_train_3 = X_train_3.to_numpy()
    X_test_3 = X_test_3.to_numpy()

    X_train = np.concatenate([X_train_1,X_train_2,X_train_3],axis=1)
    X_test = np.concatenate([X_test_1,X_test_2,X_test_3],axis=1)
    df_comparison, model = machine_learning_pipeline(X_train, X_test, y_train, y_test, ID_test, pipe=pipe) #Main pipeline. Obtain comparison of labels
    p_score_list, p_score_ID_list, rec_rate, acc = performance_metrics(df_comparison) #Get performance metrics
    p_problem = get_problematic_patients(p_score_ID_list)
    print(rec_rate)
    print(f'Grid best estimator: {model.best_estimator_}\n') if hasattr(model,'best_estimator_') else None #Print the best estimator hyperparameters of the grid search
    print(f'Best estimator PCA explained variance: {model.best_estimator_.named_steps["reductor"].explained_variance_ratio_}\n')
    all_rec_rate[fold] = rec_rate
  print(f'Average:{all_rec_rate.mean()}')
# Out:
# For magnification 40
#
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9087082371302525
# Grid best estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('reductor', PCA(n_components=0.95)),
#                 ('classifier',
#                  SVC(C=2.9918497031144344, class_weight='balanced',
#                      gamma=0.0005357589497553396))])
#
# Best estimator PCA explained variance: [0.13978326 0.11691509 0.06042964 0.04577836 0.04091022 0.03651289
#  0.0332255  0.0283872  0.02273528 0.0217425  0.02024462 0.01872558
#  0.01667126 0.01471094 0.0119776  0.01171285 0.01103857 0.01036154
#  0.00935244 0.00890508 0.0084887  0.00776875 0.00738642 0.00687588
#  0.00658573 0.00610672 0.00575833 0.00556373 0.00531212 0.00508322
#  0.00466614 0.00454629 0.00438981 0.00412047 0.00409648 0.00386395
#  0.00375999 0.00350717 0.00330305 0.0031587  0.00308052 0.00298095
#  0.0029539  0.00283577 0.00278471 0.00260739 0.00258846 0.0024763
#  0.00239707 0.00232705 0.00228683 0.0022325  0.00219548 0.00215177
#  0.00212645 0.00206265 0.00201689 0.00193359 0.00184858 0.00181325
#  0.0017859  0.00174209 0.0016874  0.00164995 0.00163598 0.0015872
#  0.00157973 0.00154958 0.00152793 0.00150676 0.00148141 0.00147042
#  0.00034398 0.00034235 0.00034019 0.00033543 0.00033448 0.00033057
#  0.0003297  0.00032802 0.00032347 0.00032305 0.00032045 0.00031675
#  0.00031454]
#
# Average:0.8423809698645817

# %% [markdown]
# ## Multiclass classification

# %% [markdown]
# ### Plain-classification (No hierarchy) (Vanilla version)

# %%
def get_multi_class(paths):
  '''
  Returns the dataframe of encoded multi classes from 0 to 7. 
  input: paths => the list of the paths in a folder.
  Benign
  B_A : adenosis (A)
  B_F : fibroadenoma (F)
  B_PT : phyllodes tumor (PT)
  B_TA : tubular adenone (TA)

  Malignant
  M_DC : ductal carcinoma (DC)
  M_LC : lobular carcinoma (LC)
  M_MC : mucinous carcinoma (MC)
  M_PC : papillary carcinoma (PC)
  '''
  classes = ['B_A', 'B_F', 'B_PT', 'B_TA', 'M_DC', 'M_LC', 'M_MC', 'M_PC']
  classes_l = []
  for path in paths:
    c = path.rsplit('/', 1)[1].split('_', 1)[1].split('-', 1)[0] 
    for slide_class in classes:
      if c == slide_class:
        classes_l.append(c)
  reps = {'B_A': 0, 'B_F': 1, 'B_PT': 2, 'B_TA': 3, 'M_DC': 4, 'M_LC': 5,'M_MC': 6, 'M_PC': 7}
  cat = [reps.get(x,x) for x in classes_l]
  return cat

# %%
paths = pickle.load(open('/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/paths.p','rb'))

def read_files_multi_class(extractor, fold, mag):
  '''
  extractor: Feature extractor - String.
  mag: Magnification factor - int.
  fold: Fold number - int.
  Reads and splits the files as X_train, y_train, X_test, y_test
  '''
  fold_convert=fold-1

  if mag == 40:
    mag_convert = 0
  if mag == 100:
    mag_convert = 1
  if mag == 200:
    mag_convert = 2
  if mag == 400:
    mag_convert = 3

  data_train=pd.read_csv(f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/fold{fold}/train/{extractor}_f{fold}_train_{mag}x_fv.csv', delimiter='\t', index_col=0)
  X_train=data_train.iloc[:,1:-1]
  y_train=np.array(get_multi_class(paths[fold_convert,0,mag_convert]))
  df_patient_train=data_train.iloc[:,0:1] # Just patient Id's

  data_test=pd.read_csv(f'/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/fold{fold}/test/{extractor}_f{fold}_test_{mag}x_fv.csv', delimiter='\t', index_col=0)
  X_test=data_test.iloc[:,1:-1]
  y_test=np.array(get_multi_class(paths[fold_convert,1,mag_convert])) 
  df_patient_test=data_test.iloc[:,0:1] # Just patient Id's

  return X_train, y_train, df_patient_train, X_test, y_test, df_patient_test

# %%
extractor='PFTAS'
average_40=avg_rec_rate(40,extractor, multi=True)
average_100=avg_rec_rate(100,extractor, multi=True)
average_200=avg_rec_rate(200,extractor, multi=True)
average_400=avg_rec_rate(400,extractor, multi=True)
print(f'Averages among magnifications: {average_40, average_100, average_200, average_400}')
# Out:
# Averages among magnifications: ((0.4032868869689814, 0.38608759517892366, 0.34093176379465273), (0.36763193750830586, 0.3435266060002509, 0.3120065046391135), (0.40449107772115517, 0.3854549518341167, 0.3532085700735391), (0.4109311159686153, 0.3854721614344069, 0.3449384000437748))

# %%
extractor='PFTAS'
average_40=avg_rec_rate(40,extractor)
average_100=avg_rec_rate(100,extractor)
average_200=avg_rec_rate(200,extractor)
average_400=avg_rec_rate(400,extractor)
print(f'Averages among magnifications: {average_40, average_100, average_200, average_400}')
# Out:
# Averages among magnifications: ((0.7008711554707434, 0.6937476647809216, 0.6728499553907232), (0.7383497267914324, 0.7339436546085664, 0.7241907639689833), (0.7255634989840556, 0.7253045347738902, 0.7150454881468997), (0.7272674479213309, 0.7214692743251229, 0.7080717285962393))

# %%
extractor='PFTAS'
rec_40, acc_40, f1_40 = avg_rec_rate(40,extractor, multi=True)
rec_100, acc_100, f1_100 = avg_rec_rate(100,extractor, multi=True)
rec_200, acc_200, f1_200 = avg_rec_rate(200,extractor, multi=True)
rec_400, acc_400, f1_400 = avg_rec_rate(400,extractor, multi=True)
print(f'Averages among magnifications: {rec_40, rec_100, rec_200, rec_400}')
print(f'Averages among magnifications: {acc_40, acc_100, acc_200, acc_400}')
print(f'Averages among magnifications: {f1_40, f1_100, f1_200, f1_400}')
# Out:
# Averages among magnifications: (0.4032868869689814, 0.36763193750830586, 0.40449107772115517, 0.4109311159686153)
# Averages among magnifications: (0.38608759517892366, 0.3435266060002509, 0.3854549518341167, 0.3854721614344069)
# Averages among magnifications: (0.34093176379465273, 0.3120065046391135, 0.3532085700735391, 0.3449384000437748)

# %%
extractor='PFTAS'
rec_40, acc_40, f1_40=avg_rec_rate(40,extractor)
rec_100, acc_100, f1_100=avg_rec_rate(100,extractor)
rec_200, acc_200, f1_200=avg_rec_rate(200,extractor)
rec_400, acc_400, f1_400=avg_rec_rate(400,extractor)
print(f'Averages among magnifications: {rec_40, rec_100, rec_200, rec_400}')
print(f'Averages among magnifications: {acc_40, acc_100, acc_200, acc_400}')
print(f'Averages among magnifications: {f1_40, f1_100, f1_200, f1_400}')
# Out:
# Averages among magnifications: (0.7008711554707434, 0.7383497267914324, 0.7255634989840556, 0.7272674479213309)
# Averages among magnifications: (0.6937476647809216, 0.7339436546085664, 0.7253045347738902, 0.7214692743251229)
# Averages among magnifications: (0.6728499553907232, 0.7241907639689833, 0.7150454881468997, 0.7080717285962393)

# %% [markdown]
# # Best models extraction

# %% [markdown]
# From the results obtained above we extract the best models

# %% [markdown]
# ## Special functions

# %%
def model_and_metrics(extractor='dense', method = 'SVM', grid = 'normal', verbose = 1, reductor_components = [1], scoring = 'accuracy', sampler = SMOTE(), max_corr=1, fold=0, mag=0):
  """
  Input ML model settings, as well as folder to extract
  :param extractor: name of extractor of features used
  :param read_files_type: type of file to be read (csv, pickle)
  :param pipe: Pipeline of the classification method.
  :param max_corr: Maximum correlation allowed between features
  :param fold, mag: known
  :return: metrics of the model + model. Additionally, problematic patients are displayed.
  """
  read_files_type=read_files_pickle if (extractor in ['dense','GLCM']) else read_files_csv #Read files type

  X_train, X_test, y_train, y_test, ID_train, ID_test = read_files_type(extractor=extractor, fold=fold, mag=mag) #Split data
  pipe = classifier_and_grid_strat(X_train, y_train, ID_train, method, grid = grid, verbose=verbose, reductor_components=reductor_components, scoring = scoring, sampler =sampler) #Defining pipe
  df_comparison, model, auc = machine_learning_pipeline_binary(X_train, X_test, y_train, y_test, ID_test, pipe=pipe, max_corr=max_corr) #Main pipeline. Obtain comparison of labels
  p_score_list, p_score_ID_list, rec_rate, acc = performance_metrics(df_comparison) #Get performance metrics
  p_problem = get_problematic_patients(p_score_ID_list)

  print(f'-For fold {fold+1} and magnification {mag_dict[mag]}:\n') #Print metrics
  print(f'Recognition rate: {rec_rate}')
  print(f'Image-wise accuracy: {acc}')
  print(f'Problematic patients: {p_problem}\n') #Show problematic patients' ID and score

  return p_score_list, p_score_ID_list, rec_rate, acc, model, auc

def machine_learning_pipeline_binary(X_train, X_test, y_train, y_test, ID_test, pipe, max_corr=1):
  """
  Main machine_learning pipeline.It receives the data (feature matrices, label and patients' ID) and produces the csv with the comparison between real and predicted labes. The model is also returned.
  
  :param X_train, X_test...etc: feature matrices, labels and patients' ID. X matrices are dataframes, the rest are np.arrays
  :param pipe: Pipeline defined using sklearn
  :param max_corr: Maximum correlation accepted among features
  :return: dataframe with the ID, prediction and real label, and model used
  """
  print(f'Input features: {X_train.shape[1]}\n')
  X_train_nocorr, X_test_nocorr = remove_correlated(X_train, X_test, max_corr=max_corr) #Remove correlated features from X_train and X_test
  print(f'No-correlated features: {X_train_nocorr.shape[1]}\n')
  model = pipe.fit(X_train_nocorr, y_train.ravel()) #Model fit
  y_pred = model.predict(X_test_nocorr) #Prediction

  fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred)
  auc = metrics.auc(fpr, tpr)

  y_pred = pd.DataFrame(y_pred) # Dataframe of predictions
  y_pred.columns = ['y_pred']
  y_test = pd.DataFrame(y_test) # Dataframe of test labels
  y_test.columns = ['y_test']
  df_comparison = pd.DataFrame(ID_test).copy() # Copy the main dataframe with Patient ID's for test set.
  df_comparison.columns = ['ID'] # Naming the column in df_p_test
  df_comparison["y_test"]=y_test["y_test"] # Adding the dataframe y_test
  df_comparison["y_pred"]=y_pred["y_pred"] # Adding the dataframe y_pred.
  df_comparison['comparison'] = np.where(df_comparison['y_test'] == df_comparison['y_pred'], 1, 0) # Adding the comparison coloumn, where y_pred==y_test, it's true.

  return df_comparison, model, auc

# %% [markdown]
# ## Extract best models

# %%
#Create matrix that will contain best models and its metrics
best_pred_binary = np.zeros((4,3),dtype='object')

# %%
#Unchangable settings
grid = 'random'
extractor = 'dense'
verbose = 3
reductor_components = [0.95,0.99]
scoring = 'MCC'
max_corr = 0.99

#Settings to change
fold = 0

######
#Depends on setting
mag = 3
method = 'RF'
sampler = SMOTE()

#Built model
p_score_list, p_score_ID_list, rec_rate, acc, model, auc = model_and_metrics(extractor=extractor, method = method, grid =grid , verbose = verbose, reductor_components = reductor_components, scoring = scoring, sampler = sampler, max_corr=max_corr, fold=fold, mag=mag)
#Save model, aAUC and accuracy
best_pred_binary[mag,:] = [model,auc,acc]

# %%
#Save best modle in pickle file
with open('/content/drive/MyDrive/Ars_machinae_autodiscentis/Inceptum/Machine_Learning/Results/Best_models/Best_pred_binary.p','wb') as handle:
  pickle.dump(best_pred_binary,handle,pickle.HIGHEST_PROTOCOL)
